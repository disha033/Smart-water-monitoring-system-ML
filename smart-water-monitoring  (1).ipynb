# %%
# Installing required packages
# !pip install xgboost pandas numpy scikit-learn matplotlib
# Out:
# Requirement already satisfied: xgboost in c:\users\user\anaconda3\envs\venv\lib\site-packages (3.0.0)
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\user\appdata\roaming\python\python313\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\envs\venv\lib\site-packages (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: scipy in c:\users\user\appdata\roaming\python\python313\site-packages (from xgboost) (1.15.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\envs\venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import xgboost as xgb

# %%
df = pd.read_csv("C:/Users/user/OneDrive/dataset/train.csv")
df_test = pd.read_csv("C:/Users/user/OneDrive/dataset/test.csv")

# %%
def process_datetime(df):
    df["Timestamp"] = pd.to_datetime(df["Timestamp"], errors="coerce")
    df["Hour"] = df["Timestamp"].dt.hour
    df["Day"] = df["Timestamp"].dt.day
    df["Month"] = df["Timestamp"].dt.month
    df["DayOfWeek"] = df["Timestamp"].dt.dayofweek
    df["IsWeekend"] = (df["DayOfWeek"] >= 5).astype(int)
    df["IsMorningPeak"] = ((df["Hour"] >= 6) & (df["Hour"] <= 9)).astype(int)
    df.drop(columns=["Timestamp"], inplace=True)
    return df

df = process_datetime(df)
df_test = process_datetime(df_test)

# %%
def fill_missing_values(df):
    num_cols = df.select_dtypes(include=["number"]).columns
    df[num_cols] = df[num_cols].fillna(df[num_cols].median())
    
    cat_cols = df.select_dtypes(include=["object"]).columns
    for col in cat_cols:
        df[col] = df[col].fillna(df[col].mode()[0])
    return df

df = fill_missing_values(df)
df_test = fill_missing_values(df_test)

# %%
def encode_categorical(df, label_encoders=None, is_train=True):
    if label_encoders is None:
        label_encoders = {}
    
    cat_cols = df.select_dtypes(include=["object"]).columns
    for col in cat_cols:
        if is_train:
            label_encoders[col] = LabelEncoder()
            df[col] = label_encoders[col].fit_transform(df[col])
        else:
            df[col] = df[col].map(lambda x: label_encoders[col].transform([x])[0] if x in label_encoders[col].classes_ else -1)
    return df, label_encoders

df, label_encoders = encode_categorical(df, is_train=True)
df_test, _ = encode_categorical(df_test, label_encoders, is_train=False)

# %%
assert df.select_dtypes(include=["object"]).empty, "Data still contains categorical values!"

X = df.drop(columns=["Water_Consumption"], errors='ignore')
y = df["Water_Consumption"] if "Water_Consumption" in df.columns else None
X_test = df_test.copy()

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X_test)

# %%
from xgboost import XGBRegressor

# %%
# 1. Split data
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 2. Initialize model (compatible with all versions)
params = {
    'objective': 'reg:squarederror',
    'n_estimators': 2000,
    'learning_rate': 0.01,
    'max_depth': 5,
    'colsample_bytree': 0.7,
    'subsample': 0.8,
    'gamma': 0.1,
    'reg_alpha': 0.1,
    'reg_lambda': 1.0,
    'random_state': 42,
    'n_jobs': -1,
    'eval_metric': 'rmse'
}

# Version detection and training
try:
    # For newer XGBoost (>=1.3.0)
    xgb_model = xgb.XGBRegressor(**params, early_stopping_rounds=50)
    xgb_model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        verbose=10
    )
except TypeError:
    # For older XGBoost (<1.3.0)
    xgb_model = xgb.XGBRegressor(**params)
    xgb_model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        early_stopping_rounds=50,
        verbose=10
    )

# 3. Evaluation
y_val_pred = xgb_model.predict(X_val)
rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
print(f"VALIDATION RMSE: {rmse:.4f}")

# 4. Final predictions
y_test_pred = xgb_model.predict(X_test_scaled)
y_test_pred = np.clip(y_test_pred, a_min=0, a_max=None)
# Out:
# [0]	validation_0-rmse:74.24900
# [10]	validation_0-rmse:69.26950
# [20]	validation_0-rmse:64.99885
# [30]	validation_0-rmse:60.99422
# [40]	validation_0-rmse:57.53599
# [50]	validation_0-rmse:54.36019
# [60]	validation_0-rmse:51.48022
# [70]	validation_0-rmse:48.79886
# [80]	validation_0-rmse:46.45341
# [90]	validation_0-rmse:44.23751
# [100]	validation_0-rmse:42.26123
# [110]	validation_0-rmse:40.38527
# [120]	validation_0-rmse:38.60561
# [130]	validation_0-rmse:37.03044
# [140]	validation_0-rmse:35.58088
# [150]	validation_0-rmse:34.22389
# [160]	validation_0-rmse:32.95596
# [170]	validation_0-rmse:31.76429
# [180]	validation_0-rmse:30.67279
# [190]	validation_0-rmse:29.68752
# [200]	validation_0-rmse:28.70975
# [210]	validation_0-rmse:27.77328
# [220]	validation_0-rmse:26.93884
# [230]	validation_0-rmse:26.14058
# [240]	validation_0-rmse:25.37917
# [250]	validation_0-rmse:24.71181
# [260]	validation_0-rmse:24.07095
# [270]	validation_0-rmse:23.51330
# [280]	validation_0-rmse:22.98614
# [290]	validation_0-rmse:22.47755
# [300]	validation_0-rmse:21.98241
# [310]	validation_0-rmse:21.52234
# [320]	validation_0-rmse:21.10580
# [330]	validation_0-rmse:20.69625
# [340]	validation_0-rmse:20.31730
# [350]	validation_0-rmse:19.95369
# [360]	validation_0-rmse:19.61103
# [370]	validation_0-rmse:19.26594
# [380]	validation_0-rmse:18.96382
# [390]	validation_0-rmse:18.64489
# [400]	validation_0-rmse:18.38852
# [410]	validation_0-rmse:18.11831
# [420]	validation_0-rmse:17.87586
# [430]	validation_0-rmse:17.65304
# [440]	validation_0-rmse:17.44196
# [450]	validation_0-rmse:17.21484
# [460]	validation_0-rmse:17.01220
# [470]	validation_0-rmse:16.81267
# [480]	validation_0-rmse:16.62694
# [490]	validation_0-rmse:16.46569
# [500]	validation_0-rmse:16.29028
# [510]	validation_0-rmse:16.14071
# [520]	validation_0-rmse:15.98778
# [530]	validation_0-rmse:15.82908
# [540]	validation_0-rmse:15.65605
# [550]	validation_0-rmse:15.51312
# [560]	validation_0-rmse:15.38745
# [570]	validation_0-rmse:15.26902
# [580]	validation_0-rmse:15.13149
# [590]	validation_0-rmse:15.02073
# [600]	validation_0-rmse:14.92588
# [610]	validation_0-rmse:14.81320
# [620]	validation_0-rmse:14.69626
# [630]	validation_0-rmse:14.61780
# [640]	validation_0-rmse:14.52405
# [650]	validation_0-rmse:14.42568
# [660]	validation_0-rmse:14.32880
# [670]	validation_0-rmse:14.23324
# [680]	validation_0-rmse:14.15493
# [690]	validation_0-rmse:14.08432
# [700]	validation_0-rmse:14.00045
# [710]	validation_0-rmse:13.92427
# [720]	validation_0-rmse:13.85274
# [730]	validation_0-rmse:13.79316
# [740]	validation_0-rmse:13.72371
# [750]	validation_0-rmse:13.66858
# [760]	validation_0-rmse:13.61940
# [1490]	validation_0-rmse:11.93359
# [1500]	validation_0-rmse:11.92691
# [1510]	validation_0-rmse:11.91927
# [1520]	validation_0-rmse:11.90933
# [1530]	validation_0-rmse:11.90328
# [1540]	validation_0-rmse:11.89096
# [1550]	validation_0-rmse:11.88524
# [1560]	validation_0-rmse:11.88241
# [1570]	validation_0-rmse:11.87719
# [1580]	validation_0-rmse:11.87226
# [1590]	validation_0-rmse:11.86781
# [1600]	validation_0-rmse:11.86315
# [1610]	validation_0-rmse:11.85659
# [1620]	validation_0-rmse:11.85389
# [1630]	validation_0-rmse:11.84656
# [1640]	validation_0-rmse:11.83895
# [1650]	validation_0-rmse:11.83401
# [1660]	validation_0-rmse:11.82550
# [1670]	validation_0-rmse:11.81879
# [1680]	validation_0-rmse:11.81329
# [1690]	validation_0-rmse:11.80998
# [1700]	validation_0-rmse:11.80599
# [1710]	validation_0-rmse:11.80148
# [1720]	validation_0-rmse:11.80018
# [1730]	validation_0-rmse:11.79868
# [1740]	validation_0-rmse:11.78999
# [1750]	validation_0-rmse:11.78742
# [1760]	validation_0-rmse:11.78521
# [1770]	validation_0-rmse:11.77979
# [1780]	validation_0-rmse:11.77492
# [1790]	validation_0-rmse:11.77143
# [1800]	validation_0-rmse:11.76675
# [1810]	validation_0-rmse:11.76461
# [1820]	validation_0-rmse:11.76200
# [1830]	validation_0-rmse:11.75717
# [1840]	validation_0-rmse:11.75362
# [1850]	validation_0-rmse:11.74973
# [1860]	validation_0-rmse:11.74607
# [1870]	validation_0-rmse:11.74058
# [1880]	validation_0-rmse:11.73327
# [1890]	validation_0-rmse:11.72905
# [1900]	validation_0-rmse:11.72274
# [1910]	validation_0-rmse:11.72072
# [1920]	validation_0-rmse:11.72124
# [1930]	validation_0-rmse:11.72002
# [1940]	validation_0-rmse:11.71587
# [1950]	validation_0-rmse:11.71314
# [1960]	validation_0-rmse:11.70880
# [1970]	validation_0-rmse:11.70708
# [1980]	validation_0-rmse:11.70074
# [1990]	validation_0-rmse:11.69214
# [1999]	validation_0-rmse:11.68907
# VALIDATION RMSE: 11.6886

# %%
# 1. Generate predictions
y_test_pred = xgb_model.predict(X_test_scaled)
y_test_pred_rounded = np.round(y_test_pred, 2)

# 2. Create submission DataFrame 
submission = pd.DataFrame({
    'Timestamp': pd.read_csv("C:/Users/user/OneDrive/dataset/test.csv")['Timestamp'],
    'Water_Consumption': np.round(y_test_pred, 2)  # Strict 2 decimal rounding
})

# 3. Save without index
submission.to_csv("C:/Users/user/OneDrive/dataset/submission_final.csv", index=False)

# 4. Show first 5 rows 
print(submission.head())
# Out:
#        Timestamp  Water_Consumption
# 0  11/10/2014 16         311.750000
# 1  12/10/2014 00         178.289993
# 2  12/10/2014 08          77.940002
# 3  12/10/2014 16         127.629997
# 4  13/10/2014 00         126.970001
